# %%
import qrcode


# Initialize geolocator
geolocator = Nominatim(user_agent="geoapiExercises")

# Get user's current location
def get_user_location():
    location = geolocator.geocode("My location")
    if location is not None:
        return (location.latitude, location.longitude)
    else:
        return None

# Function to get user input
def get_user_input():
    student_name = input("Enter your name: ")
    student_id = input("Enter your ID: ")
    class_name = input("Enter your class: ")
    return student_name, student_id, class_name

# Function to generate QR code
def generate_qr_code(data, filename, lat, lon):
    # Create QR code instance
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )

    # Add data to the QR code
    qr.add_data(data)
    qr.make(fit=True)

    # Generate QR code image
    img = qr.make_image(fill_color="black", back_color="white")

    # Add location to the QR code
    data = data + "\nLocation: " + str(lat) + "," + str(lon)

    # Clear the screen
    print("\033c")

    # Generate QR code image
    img = qr.make_image(fill_color="black", back_color="white")

    # Save QR code image to file
    img.save(filename)



# Generate QR code with relevant information encoded
if location is not None:
    data = f"Student Name: {student_name}\nStudent ID: {student_id}\nClass: {class_name}\n"
    
    print(f"QR code with student name: {student_name}, ID: {student_id}, class: {class_name}, and location: {location} has been saved to {filename}")
else:
    print("Failed to get user's current location")
